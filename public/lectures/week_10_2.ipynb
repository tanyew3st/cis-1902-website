# %%
import requests

# %%
# A GET request is used to request data from a specified resource.

response = requests.get("https://httpbin.org/get")

print(f"Status Code: {response.status_code}")
print(f"Response Body: {response.text}")
# Out:
# Status Code: 200
# Response Body: {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br, zstd",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-660c7e2f-3679e8391b37a1b554afc70a"
#   },
#   "origin": "165.123.227.233",
#   "url": "https://httpbin.org/get"
# }

# %%
# Query parameters are a defined set of parameters attached to the end of a url.
# They are extensions of the URL that are used to help define specific content or actions based on the data being passed.

params = {"key1": "value1", "key2": "value2"}

response = requests.get("https://httpbin.org/get", params=params)

# print the url that we have accesssed
# what coudl this look like in the browser?
print(response.json())
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-660c7f34-1f40f5556ed18de2469f7bf2'}, 'origin': '165.123.227.233', 'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
# A POST request is used to send data to the server to create/update a resource.
# The data is sent in the body of the request.

data = {"username": "john", "password": "secret"}

response = requests.post("https://httpbin.org/post", data=data)

# The server responds with JSON data including form data we sent.
# We can convert the response to a JSON object:
# (Great place to test out post / general requests is Postman!)

print(response.json())
# Out:
# {'args': {}, 'data': '', 'files': {}, 'form': {'password': 'secret', 'username': 'john'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '29', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-660c7f69-7fc576317944ce5f4c26ba75'}, 'json': None, 'origin': '165.123.227.233', 'url': 'https://httpbin.org/post'}

# %%
# Many API responses are formatted in JSON. The requests library has a built-in method to handle this.

response = requests.get("https://httpbin.org/json")

# We can directly convert the response to a Python dictionary using .json()

data = response.json()

# Now you can work with the JSON data directly in Python.

print(data)

# pretty print data
import json

print(json.dumps(data, indent=2))
# Out:
# {'slideshow': {'author': 'Yours Truly', 'date': 'date of publication', 'slides': [{'title': 'Wake up to WonderWidgets!', 'type': 'all'}, {'items': ['Why <em>WonderWidgets</em> are great', 'Who <em>buys</em> WonderWidgets'], 'title': 'Overview', 'type': 'all'}], 'title': 'Sample Slide Show'}}
# {
#   "slideshow": {
#     "author": "Yours Truly",
#     "date": "date of publication",
#     "slides": [
#       {
#         "title": "Wake up to WonderWidgets!",
#         "type": "all"
#       },
#       {
#         "items": [
#           "Why <em>WonderWidgets</em> are great",
#           "Who <em>buys</em> WonderWidgets"
#         ],
#         "title": "Overview",
#         "type": "all"
#       }
#     ],
#     "title": "Sample Slide Show"
#   }
# }

# %%
response = requests.get("https://httpbin.org/json")
data = response.json()
print(json.dumps(data, indent=2))

# JSON is just a dictionary in Python
print(data["slideshow"]["author"])
# Out:
# {
#   "slideshow": {
#     "author": "Yours Truly",
#     "date": "date of publication",
#     "slides": [
#       {
#         "title": "Wake up to WonderWidgets!",
#         "type": "all"
#       },
#       {
#         "items": [
#           "Why <em>WonderWidgets</em> are great",
#           "Who <em>buys</em> WonderWidgets"
#         ],
#         "title": "Overview",
#         "type": "all"
#       }
#     ],
#     "title": "Sample Slide Show"
#   }
# }
# Yours Truly

# %%
# Sometimes you need to send custom headers with your requests.
# For example, many APIs require an 'Authorization' header.

headers = {"Authorization": "Bearer your_access_token_here", "Custom-Header": "value"}

response = requests.get("https://httpbin.org/headers", headers=headers)

# The server echoes back the headers we sent.
# Let's check the custom headers in the response:

print(response.json())
# Out:
# {'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Authorization': 'Bearer your_access_token_here', 'Custom-Header': 'value', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-660c8026-3f087120170e65d615bc789e'}}

# %%
# A PATCH request is used to apply partial modifications to a resource.

data = {
    "username": "john",
    "email": "john@example.com",  # Let's say we're updating the user's email.
}

response = requests.patch("https://httpbin.org/patch", data=json.dumps(data))

# The server returns the data that was sent in the request.
# This is useful for confirming what changes were applied.

print(response.json())
# Out:
# {'args': {}, 'data': '{"username": "john", "email": "john@example.com"}', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '49', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-660c8055-149050a013812dcc05d792e8'}, 'json': {'email': 'john@example.com', 'username': 'john'}, 'origin': '165.123.227.233', 'url': 'https://httpbin.org/patch'}

# %%
# A DELETE request is used to delete a specific resource.

response = requests.delete("https://httpbin.org/delete", json={"key": "value"})

# Similar to other methods, the server echoes back data about the request.
# This confirms that our DELETE request was received.

print(response.json())
# Out:
# {'args': {}, 'data': '{"key": "value"}', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '16', 'Content-Type': 'application/json', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-660c806e-2ae2f53a35b1755a522c95a6'}, 'json': {'key': 'value'}, 'origin': '165.123.227.233', 'url': 'https://httpbin.org/delete'}

# %%
import requests


# https://developer.spotify.com/documentation/web-api/reference/search
def search_tracks(query, access_token):
    url = "https://api.spotify.com/v1/search"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {"q": query, "type": "track", "limit": 10}
    response = requests.get(url, headers=headers, params=params)
    return response.json()


# Example usage
query = "Never Gonna Give You Up"
access_token = "BQD3fo0yDacBQITWVBTLtkz5JrFii7SVswbmVZ0khVViCIFnhpMMARVBOMocQw7vxXG9Qkg_3a04JKl13PcERE8oh8EOZOzcgz4hL246YZBJtqzgs3Q"
search_results = search_tracks(query, access_token)
# print(search_results)

# pretty print this
print(json.dumps(search_results, indent=2))
# Out:
# {
#   "tracks": {
#     "href": "https://api.spotify.com/v1/search?query=Never+Gonna+Give+You+Up&type=track&offset=0&limit=10",
#     "items": [
#       {
#         "album": {
#           "album_type": "album",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/0gxyHStUsqpMadRV0Di1Qt"
#               },
#               "href": "https://api.spotify.com/v1/artists/0gxyHStUsqpMadRV0Di1Qt",
#               "id": "0gxyHStUsqpMadRV0Di1Qt",
#               "name": "Rick Astley",
#               "type": "artist",
#               "uri": "spotify:artist:0gxyHStUsqpMadRV0Di1Qt"
#             }
#           ],
#           "available_markets": [
#             "AR",
#             "AU",
#             "AT",
#             "BE",
#             "BO",
#             "BR",
#             "BG",
#             "CA",
#             "CL",
#             "CO",
#             "CR",
#             "CY",
#             "CZ",
#             "DK",
#             "DO",
#             "DE",
#             "EC",
#             "EE",
#             "SV",
#             "FI",
#             "FR",
#             "GR",
#             "GT",
#             "HN",
#             "HK",
#             "HU",
#             "IS",
#             "IE",
#             "IT",
#             "LV",
#             "LT",
#             "LU",
#             "MY",
#             "MT",
#             "MX",
#             "NL",
#             "NZ",
#             "NI",
#             "NO",
#             "PA",
#             "PY",
#             "PE",
#             "PH",
#             "PL",
#             "PT",
#             "SG",
#             "SK",
#             "ES",
#             "SE",
#             "CH",
#             "TW",
#             "TR",
#             "UY",
#             "US",
#             "GB",
#             "AD",
#             "LI",
#             "MC",
#             "ID",
#             "JP",
#             "TH",
#             "VN",
#             "RO",
#             "IL",
#             "ZA",
#             "SA",
#             "AE",
#             "BH",
#             "QA",
#             "OM",
#             "KW",
#             "EG",
#             "MA",
#             "DZ",
#             "TN",
#             "LB",
#             "JO",
#             "PS",
#             "IN",
#             "BY",
#             "KZ",
#             "MD",
#             "UA",
#             "AL",
#             "BA",
#             "HR",
#             "ME",
#             "MK",
#             "RS",
#             "SI",
#             "KR",
#             "BD",
#             "PK",
#             "LK",
#             "GH",
#             "KE",
#             "NG",
#             "TZ",
#             "UG",
#             "AG",
#             "AM",
#             "BS",
#             "BB",
#             "BZ",
#             "BT",
#             "BW",
#             "BF",
#             "CV",
#             "CW",
#             "DM",
#             "FJ",
#             "GM",
#             "GE",
#             "GD",
#             "GW",
#             "GY",
#             "HT",
#             "JM",
#             "KI",
#             "LS",
#             "LR",
#             "MW",
#             "MV",
#             "ML",
#             "MH",
#             "FM",
#             "NA",
#             "NR",
#             "NE",
#             "PW",
#             "PG",
#             "PR",
#             "WS",
#             "SM",
#             "ST",
#             "SN",
#             "SC",
#             "SL",
#             "SB",
#             "KN",
#             "LC",
#             "VC",
#             "SR",
#             "TL",
#             "TO",
#             "TT",
#             "TV",
#             "VU",
#             "AZ",
#             "BN",
#             "BI",
#             "KH",
#             "CM",
#             "TD",
#             "KM",
#             "GQ",
#             "SZ",
#             "GA",
#             "GN",
#             "KG",
#             "LA",
#             "MO",
#             "MR",
#             "MN",
#             "NP",
#             "RW",
#             "TG",
#             "UZ",
#             "ZW",
#             "BJ",
#             "MG",
#             "MU",
#             "MZ",
#             "AO",
#             "CI",
#             "DJ",
#             "ZM",
#             "CD",
#             "CG",
#             "IQ",
#             "LY",
#             "TJ",
#             "VE",
#             "ET",
#             "XK"
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/6eUW0wxWtzkFdaEFsTJto6"
#           },
#           "href": "https://api.spotify.com/v1/albums/6eUW0wxWtzkFdaEFsTJto6",
#           "id": "6eUW0wxWtzkFdaEFsTJto6",
#           "images": [
#             {
#               "height": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b27315ebbedaacef61af244262a8",
#               "width": 640
#             },
#             {
#               "height": 300,
#               "url": "https://i.scdn.co/image/ab67616d00001e0215ebbedaacef61af244262a8",
#               "width": 300
#             },
#             {
#               "height": 64,
#               "url": "https://i.scdn.co/image/ab67616d0000485115ebbedaacef61af244262a8",
#               "width": 64
#             }
#           ],
#           "name": "Whenever You Need Somebody",
#           "release_date": "1987-11-12",
#           "release_date_precision": "day",
#           "total_tracks": 10,
#           "type": "album",
#           "uri": "spotify:album:6eUW0wxWtzkFdaEFsTJto6"
#         },
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/0gxyHStUsqpMadRV0Di1Qt"
#             },
#             "href": "https://api.spotify.com/v1/artists/0gxyHStUsqpMadRV0Di1Qt",
#             "id": "0gxyHStUsqpMadRV0Di1Qt",
#             "name": "Rick Astley",
#             "type": "artist",
#             "uri": "spotify:artist:0gxyHStUsqpMadRV0Di1Qt"
#           }
#         ],
#         "available_markets": [
#           "AR",
#           "AU",
#           "AT",
#           "BE",
#           "BO",
#           "BR",
#           "BG",
#           "CA",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DK",
#           "DO",
#           "DE",
#           "EC",
#           "EE",
#           "SV",
#           "FI",
#           "FR",
#           "GR",
#           "GT",
#           "HN",
#           "HK",
#           "HU",
#           "IS",
#           "IE",
#           "IT",
#           "LV",
#           "LT",
#           "LU",
#           "MY",
#           "MT",
#           "MX",
#           "NL",
#           "NZ",
#           "NI",
#           "NO",
#           "PA",
#           "PY",
#           "PE",
#           "PH",
#           "PL",
#           "PT",
#           "SG",
#           "SK",
#           "ES",
#           "SE",
#           "CH",
#           "TW",
#           "TR",
#           "UY",
#           "US",
#           "GB",
#           "AD",
#           "LI",
#           "MC",
#           "ID",
#           "JP",
#           "TH",
#           "VN",
#           "RO",
#           "IL",
#           "ZA",
#           "SA",
#           "AE",
#           "BH",
#           "QA",
#           "OM",
#           "KW",
#           "EG",
#           "MA",
#           "DZ",
#           "TN",
#           "LB",
#           "JO",
#           "PS",
#           "IN",
#           "BY",
#           "KZ",
#           "MD",
#           "UA",
#           "AL",
#           "BA",
#           "HR",
#           "ME",
#           "MK",
#           "RS",
#           "SI",
#           "KR",
#           "BD",
#           "PK",
#           "LK",
#           "GH",
#           "KE",
#           "NG",
#           "TZ",
#           "UG",
#           "AG",
#           "AM",
#           "BS",
#           "BB",
#           "BZ",
#           "BT",
#           "BW",
#           "BF",
#           "CV",
#           "CW",
#           "DM",
#           "FJ",
#           "GM",
#           "GE",
#           "GD",
#           "GW",
#           "GY",
#           "HT",
#           "JM",
#           "KI",
#           "LS",
#           "LR",
#           "MW",
#           "MV",
#           "ML",
#           "MH",
#           "FM",
#           "NA",
#           "NR",
#           "NE",
#           "PW",
#           "PG",
#           "WS",
#           "SM",
#           "ST",
#           "SN",
#           "SC",
#           "SL",
#           "SB",
#           "KN",
#           "LC",
#           "VC",
#           "SR",
#           "TL",
#           "TO",
#           "TT",
#           "TV",
#           "VU",
#           "AZ",
#           "BN",
#           "BI",
#           "KH",
#           "CM",
#           "TD",
#           "KM",
#           "GQ",
#           "SZ",
#           "GA",
#           "GN",
#           "KG",
#           "LA",
#           "MO",
#           "MR",
#           "MN",
#           "NP",
#           "RW",
#           "TG",
#           "UZ",
#           "ZW",
#           "BJ",
#           "MG",
#           "MU",
#           "MZ",
#           "AO",
#           "CI",
#           "DJ",
#           "ZM",
#           "CD",
#           "CG",
#           "IQ",
#           "LY",
#           "TJ",
#           "VE",
#           "ET",
#           "XK"
#         ],
#         "disc_number": 1,
#         "duration_ms": 213573,
#         "explicit": false,
#         "external_ids": {
#           "isrc": "GBARL9300135"
#         },
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/4PTG3Z6ehGkBFwjybzWkR8"
#         },
#         "href": "https://api.spotify.com/v1/tracks/4PTG3Z6ehGkBFwjybzWkR8",
#         "id": "4PTG3Z6ehGkBFwjybzWkR8",
#         "is_local": false,
#         "name": "Never Gonna Give You Up",
#         "popularity": 79,
#         "preview_url": "https://p.scdn.co/mp3-preview/b4c682084c3fd05538726d0a126b7e14b6e92c83?cid=03bc53377a004f35a1305a462e790be6",
#         "track_number": 1,
#         "type": "track",
#         "uri": "spotify:track:4PTG3Z6ehGkBFwjybzWkR8"
#       },
#       {
#         "album": {
#           "album_type": "album",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/5e6l2ue9kA8MNkch1M8OYn"
#               },
#               "href": "https://api.spotify.com/v1/artists/5e6l2ue9kA8MNkch1M8OYn",
#               "id": "5e6l2ue9kA8MNkch1M8OYn",
#               "name": "Purple Lions",
#               "type": "artist",
#               "uri": "spotify:artist:5e6l2ue9kA8MNkch1M8OYn"
#             }
#           ],
#           "available_markets": [
#             "AR",
#             "AU",
#             "AT",
#             "BE",
#             "BO",
#             "BR",
#             "BG",
#             "CA",
#             "CL",
#             "CO",
#             "CR",
#             "CY",
#             "CZ",
#             "DK",
#             "DO",
#             "DE",
#             "EC",
#             "EE",
#             "SV",
#             "FI",
#             "FR",
#             "GR",
#             "GT",
#             "HN",
#             "HK",
#             "HU",
#             "IS",
#             "IE",
#             "IT",
#             "LV",
#             "LT",
#             "LU",
#             "MY",
#             "MT",
#             "MX",
#             "NL",
#             "NZ",
#             "NI",
#             "NO",
#             "PA",
#             "PY",
#             "PE",
#             "PH",
#             "PL",
#             "PT",
#             "SG",
#             "SK",
#             "ES",
#             "SE",
#             "CH",
#             "TW",
#             "TR",
#             "UY",
#             "US",
#             "GB",
#             "AD",
#             "LI",
#             "MC",
#             "ID",
#             "JP",
#             "TH",
#             "VN",
#             "RO",
#             "IL",
#             "ZA",
#             "SA",
#             "AE",
#             "BH",
#             "QA",
#             "OM",
#             "KW",
#             "EG",
#             "MA",
#             "DZ",
#             "TN",
#             "LB",
#             "JO",
#             "PS",
#             "IN",
#             "BY",
#             "KZ",
#             "MD",
#             "UA",
#             "AL",
#             "BA",
#             "HR",
#             "ME",
#             "MK",
#             "RS",
#             "SI",
#             "KR",
#             "BD",
#             "PK",
#             "LK",
#             "GH",
#             "KE",
#             "NG",
#             "TZ",
#             "UG",
#             "AG",
#             "AM",
#             "BS",
#             "BB",
#             "BZ",
#             "BT",
#             "BW",
#             "BF",
#             "CV",
#             "CW",
#             "DM",
#             "FJ",
#             "GM",
#             "GE",
#             "GD",
#             "GW",
#             "GY",
#             "HT",
#             "JM",
#             "KI",
#             "LS",
#             "LR",
#             "MW",
#             "MV",
#             "ML",
#             "MH",
#             "FM",
#             "NA",
#             "NR",
#             "NE",
#             "PW",
#             "PG",
#             "PR",
#             "WS",
#             "SM",
#             "ST",
#             "SN",
#             "SC",
#             "SL",
#             "SB",
#             "KN",
#             "LC",
#             "VC",
#             "SR",
#             "TL",
#             "TO",
#             "TT",
#             "TV",
#             "VU",
#             "AZ",
#             "BN",
#             "BI",
#             "KH",
#             "CM",
#             "TD",
#             "KM",
#             "GQ",
#             "SZ",
#             "GA",
#             "GN",
#             "KG",
#             "LA",
#             "MO",
#             "MR",
#             "MN",
#             "NP",
#             "RW",
#             "TG",
#             "UZ",
#             "ZW",
#             "BJ",
#             "MG",
#             "MU",
#             "MZ",
#             "AO",
#             "CI",
#             "DJ",
#             "ZM",
#             "CD",
#             "CG",
#             "IQ",
#             "LY",
#             "TJ",
#             "VE",
#             "ET",
#             "XK"
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/1VFAtUvOJJRLyr9Q83B8Qq"
#           },
#           "href": "https://api.spotify.com/v1/albums/1VFAtUvOJJRLyr9Q83B8Qq",
#           "id": "1VFAtUvOJJRLyr9Q83B8Qq",
#           "images": [
#             {
#               "height": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b27397f0270d62c1f50efb8d0995",
#               "width": 640
#             },
#             {
#               "height": 300,
#               "url": "https://i.scdn.co/image/ab67616d00001e0297f0270d62c1f50efb8d0995",
#               "width": 300
#             },
#             {
#               "height": 64,
#               "url": "https://i.scdn.co/image/ab67616d0000485197f0270d62c1f50efb8d0995",
#               "width": 64
#             }
#           ],
#           "name": "Drops of Memory",
#           "release_date": "2019-05-09",
#           "release_date_precision": "day",
#           "total_tracks": 27,
#           "type": "album",
#           "uri": "spotify:album:1VFAtUvOJJRLyr9Q83B8Qq"
#         },
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/5e6l2ue9kA8MNkch1M8OYn"
#             },
#             "href": "https://api.spotify.com/v1/artists/5e6l2ue9kA8MNkch1M8OYn",
#             "id": "5e6l2ue9kA8MNkch1M8OYn",
#             "name": "Purple Lions",
#             "type": "artist",
#             "uri": "spotify:artist:5e6l2ue9kA8MNkch1M8OYn"
#           }
#         ],
#         "available_markets": [
#           "AR",
#           "AU",
#           "AT",
#           "BE",
#           "BO",
#           "BR",
#           "BG",
#           "CA",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DK",
#           "DO",
#           "DE",
#           "EC",
#           "EE",
#           "SV",
#           "FI",
#           "FR",
#           "GR",
#           "GT",
#           "HN",
#           "HK",
#           "HU",
#           "IS",
#           "IE",
#           "IT",
#           "LV",
#           "LT",
#           "LU",
#           "MY",
#           "MT",
#           "MX",
#           "NL",
#           "NZ",
#           "NI",
#           "NO",
#           "PA",
#           "PY",
#           "PE",
#           "PH",
#           "PL",
#           "PT",
#           "SG",
#           "SK",
#           "ES",
#           "SE",
#           "CH",
#           "TW",
#           "TR",
#           "UY",
#           "US",
#           "GB",
#           "AD",
#           "LI",
#           "MC",
#           "ID",
#           "JP",
#           "TH",
#           "VN",
#           "RO",
#           "IL",
#           "ZA",
#           "SA",
#           "AE",
#           "BH",
#           "QA",
#           "OM",
#           "KW",
#           "EG",
#           "MA",
#           "DZ",
#           "TN",
#           "LB",
#           "JO",
#           "PS",
#           "IN",
#           "BY",
#           "KZ",
#           "MD",
#           "UA",
#           "AL",
#           "BA",
#           "HR",
#           "ME",
#           "MK",
#           "RS",
#           "SI",
#           "KR",
#           "BD",
#           "PK",
#           "LK",
#           "GH",
#           "KE",
#           "NG",
#           "TZ",
#           "UG",
#           "AG",
#           "AM",
#           "BS",
#           "BB",
#           "BZ",
#           "BT",
#           "BW",
#           "BF",
#           "CV",
#           "CW",
#           "DM",
#           "FJ",
#           "GM",
#           "GE",
#           "GD",
#           "GW",
#           "GY",
#           "HT",
#           "JM",
#           "KI",
#           "LS",
#           "LR",
#           "MW",
#           "MV",
#           "ML",
#           "MH",
#           "FM",
#           "NA",
#           "NR",
#           "NE",
#           "PW",
#           "PG",
#           "WS",
#           "SM",
#           "ST",
#           "SN",
#           "SC",
#           "SL",
#           "SB",
#           "KN",
#           "LC",
#           "VC",
#           "SR",
#           "TL",
#           "TO",
#           "TT",
#           "TV",
#           "VU",
#           "AZ",
#           "BN",
#           "BI",
#           "KH",
#           "CM",
#           "TD",
#           "KM",
#           "GQ",
#           "SZ",
#           "GA",
#           "GN",
#           "KG",
#           "LA",
#           "MO",
#           "MR",
#           "MN",
#           "NP",
#           "RW",
#           "TG",
#           "UZ",
#           "ZW",
#           "BJ",
#           "MG",
#           "MU",
#           "MZ",
#           "AO",
#           "CI",
#           "DJ",
#           "ZM",
#           "CD",
#           "CG",
#           "IQ",
#           "LY",
#           "TJ",
#           "VE",
#           "ET",
#           "XK"
#         ],
#         "disc_number": 1,
#         "duration_ms": 198482,
#         "explicit": false,
#         "external_ids": {
#           "isrc": "GBSMU6393814"
#         },
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/2spOYaDYMio2TJFxh1G78s"
#         },
#         "href": "https://api.spotify.com/v1/tracks/2spOYaDYMio2TJFxh1G78s",
#         "id": "2spOYaDYMio2TJFxh1G78s",
#         "is_local": false,
#         "name": "Never Gonna Give You Up",
#         "popularity": 44,
#         "preview_url": "https://p.scdn.co/mp3-preview/9f6a723f16d36372b2a13628b24aaf4f1deed6b8?cid=03bc53377a004f35a1305a462e790be6",
#         "track_number": 26,
#         "type": "track",
#         "uri": "spotify:track:2spOYaDYMio2TJFxh1G78s"
#       },
#       {
#         "album": {
#           "album_type": "album",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz"
#               },
#               "href": "https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz",
#               "id": "7mnBLXK823vNxN3UWB7Gfz",
#               "name": "The Black Keys",
#               "type": "artist",
#               "uri": "spotify:artist:7mnBLXK823vNxN3UWB7Gfz"
#             }
#           ],
#           "available_markets": [
#             "CA",
#             "US"
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/7qE6RXYyz5kj5Tll7mJU0v"
#           },
#           "href": "https://api.spotify.com/v1/albums/7qE6RXYyz5kj5Tll7mJU0v",
#           "id": "7qE6RXYyz5kj5Tll7mJU0v",
#           "images": [
#             {
#               "height": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b27343f5bd543a2a1ab37fb40a8b",
#               "width": 640
#             },
#             {
#               "height": 300,
#               "url": "https://i.scdn.co/image/ab67616d00001e0243f5bd543a2a1ab37fb40a8b",
#               "width": 300
#             },
#             {
#               "height": 64,
#               "url": "https://i.scdn.co/image/ab67616d0000485143f5bd543a2a1ab37fb40a8b",
#               "width": 64
#             }
#           ],
#           "name": "Brothers",
#           "release_date": "2010-05-18",
#           "release_date_precision": "day",
#           "total_tracks": 15,
#           "type": "album",
#           "uri": "spotify:album:7qE6RXYyz5kj5Tll7mJU0v"
#         },
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz"
#             },
#             "href": "https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz",
#             "id": "7mnBLXK823vNxN3UWB7Gfz",
#             "name": "The Black Keys",
#             "type": "artist",
#             "uri": "spotify:artist:7mnBLXK823vNxN3UWB7Gfz"
#           }
#         ],
#         "available_markets": [
#           "CA",
#           "US"
#         ],
#         "disc_number": 1,
#         "duration_ms": 218986,
#         "explicit": false,
#         "external_ids": {
#           "isrc": "USNO11000089"
#         },
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/4qjqO5m5e5vebk9upd7xUU"
#         },
#         "href": "https://api.spotify.com/v1/tracks/4qjqO5m5e5vebk9upd7xUU",
#         "id": "4qjqO5m5e5vebk9upd7xUU",
#         "is_local": false,
#         "name": "Never Gonna Give You Up",
#         "popularity": 43,
#         "preview_url": "https://p.scdn.co/mp3-preview/431165779eae731e8ac0dc12da3856d1f47644d3?cid=03bc53377a004f35a1305a462e790be6",
#         "track_number": 14,
#         "type": "track",
#         "uri": "spotify:track:4qjqO5m5e5vebk9upd7xUU"
#       },
#       {
#         "album": {
#           "album_type": "compilation",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#               },
#               "href": "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#               "id": "0LyfQWJT6nXafLPZqxe9Of",
#               "name": "Various Artists",
#               "type": "artist",
#               "uri": "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#             }
#           ],
#           "available_markets": [
#             "AD",
#             "AE",
#             "AL",
#             "AM",
#             "AT",
#             "AU",
#             "AZ",
#             "BA",
#             "BD",
#             "BE",
#             "BG",
#             "BH",
#             "BI",
#             "BN",
#             "BT",
#             "BW",
#             "CH",
#             "CY",
#             "CZ",
#             "DE",
#             "DJ",
#             "DK",
#             "EE",
#             "EG",
#             "ES",
#             "ET",
#             "FI",
#             "FJ",
#             "FM",
#             "FR",
#             "GE",
#             "GR",
#             "HK",
#             "HR",
#             "HU",
#             "ID",
#             "IL",
#             "IN",
#             "IQ",
#             "IT",
#             "JO",
#             "KE",
#             "KG",
#             "KH",
#             "KI",
#             "KM",
#             "KR",
#             "KW",
#             "KZ",
#             "LA",
#             "LB",
#             "LI",
#             "LK",
#             "LS",
#             "LT",
#             "LU",
#             "LV",
#             "LY",
#             "MC",
#             "MD",
#             "ME",
#             "MG",
#             "MH",
#             "MK",
#             "MN",
#             "MO",
#             "MT",
#             "MU",
#             "MV",
#             "MW",
#             "MY",
#             "MZ",
#             "NA",
#             "NL",
#             "NO",
#             "NP",
#             "NR",
#             "NZ",
#             "OM",
#             "PG",
#             "PH",
#             "PK",
#             "PL",
#             "PS",
#             "PW",
#             "QA",
#             "RO",
#             "RS",
#             "RW",
#             "SA",
#             "SB",
#             "SC",
#             "SE",
#             "SG",
#             "SI",
#             "SK",
#             "SM",
#             "SZ",
#             "TH",
#             "TJ",
#             "TL",
#             "TO",
#             "TR",
#             "TV",
#             "TW",
#             "TZ",
#             "UA",
#             "UG",
#             "UZ",
#             "VN",
#             "VU",
#             "WS",
#             "XK",
#             "ZA",
#             "ZM",
#             "ZW",
#             "AO",
#             "BJ",
#             "CD",
#             "CG",
#             "CM",
#             "DZ",
#             "GA",
#             "GB",
#             "GQ",
#             "IE",
#             "NE",
#             "NG",
#             "PT",
#             "TD",
#             "TN",
#             "BF",
#             "CI",
#             "GH",
#             "GM",
#             "GN",
#             "GW",
#             "IS",
#             "LR",
#             "MA",
#             "ML",
#             "MR",
#             "SL",
#             "SN",
#             "ST",
#             "TG",
#             "CV",
#             "AR",
#             "BR",
#             "CL",
#             "SR",
#             "UY",
#             "AG",
#             "BB",
#             "BO",
#             "BS",
#             "CA",
#             "CW",
#             "DM",
#             "DO",
#             "GD",
#             "GY",
#             "HT",
#             "KN",
#             "LC",
#             "PR",
#             "PY",
#             "TT",
#             "US",
#             "VC",
#             "VE",
#             "CO",
#             "EC",
#             "JM",
#             "PA",
#             "PE",
#             "BZ",
#             "CR",
#             "GT",
#             "HN",
#             "MX",
#             "NI",
#             "SV"
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/68kCWBPmq84iv1UD1pyCZg"
#           },
#           "href": "https://api.spotify.com/v1/albums/68kCWBPmq84iv1UD1pyCZg",
#           "id": "68kCWBPmq84iv1UD1pyCZg",
#           "images": [
#             {
#               "height": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b27354c764db0c75868228267688",
#               "width": 640
#             },
#             {
#               "height": 300,
#               "url": "https://i.scdn.co/image/ab67616d00001e0254c764db0c75868228267688",
#               "width": 300
#             },
#             {
#               "height": 64,
#               "url": "https://i.scdn.co/image/ab67616d0000485154c764db0c75868228267688",
#               "width": 64
#             }
#           ],
#           "name": "musik anti ngantuk di perjalanan",
#           "release_date": "2024-04-02",
#           "release_date_precision": "day",
#           "total_tracks": 25,
#           "type": "album",
#           "uri": "spotify:album:68kCWBPmq84iv1UD1pyCZg"
#         },
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz"
#             },
#             "href": "https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz",
#             "id": "7mnBLXK823vNxN3UWB7Gfz",
#             "name": "The Black Keys",
#             "type": "artist",
#             "uri": "spotify:artist:7mnBLXK823vNxN3UWB7Gfz"
#           }
#         ],
#         "available_markets": [
#           "AD",
#           "AE",
#           "AL",
#           "AM",
#           "AT",
#           "AU",
#           "AZ",
#           "BA",
#           "BD",
#           "BE",
#           "BG",
#           "BH",
#           "BI",
#           "BN",
#           "BT",
#           "BW",
#           "CH",
#           "CY",
#           "CZ",
#           "DE",
#           "DJ",
#           "DK",
#           "EE",
#           "EG",
#           "ES",
#           "ET",
#           "FI",
#           "FJ",
#           "FM",
#           "FR",
#           "GE",
#           "GR",
#           "HK",
#           "HR",
#           "HU",
#           "ID",
#           "IL",
#           "IN",
#           "IQ",
#           "IT",
#           "JO",
#           "KE",
#           "KG",
#           "KH",
#           "KI",
#           "KM",
#           "KR",
#           "KW",
#           "KZ",
#           "LA",
#           "LB",
#           "LI",
#           "LK",
#           "LS",
#           "LT",
#           "LU",
#           "LV",
#           "LY",
#           "MC",
#           "MD",
#           "ME",
#           "MG",
#           "MH",
#           "MK",
#           "MN",
#           "MO",
#           "MT",
#           "MU",
#           "MV",
#           "MW",
#           "MY",
#           "MZ",
#           "NA",
#           "NL",
#           "NO",
#           "NP",
#           "NR",
#           "NZ",
#           "OM",
#           "PG",
#           "PH",
#           "PK",
#           "PL",
#           "PS",
#           "PW",
#           "QA",
#           "RO",
#           "RS",
#           "RW",
#           "SA",
#           "SB",
#           "SC",
#           "SE",
#           "SG",
#           "SI",
#           "SK",
#           "SM",
#           "SZ",
#           "TH",
#           "TJ",
#           "TL",
#           "TO",
#           "TR",
#           "TV",
#           "TW",
#           "TZ",
#           "UA",
#           "UG",
#           "UZ",
#           "VN",
#           "VU",
#           "WS",
#           "XK",
#           "ZA",
#           "ZM",
#           "ZW",
#           "AO",
#           "BJ",
#           "CD",
#           "CG",
#           "CM",
#           "DZ",
#           "GA",
#           "GB",
#           "GQ",
#           "IE",
#           "NE",
#           "NG",
#           "PT",
#           "TD",
#           "TN",
#           "BF",
#           "CI",
#           "GH",
#           "GM",
#           "GN",
#           "GW",
#           "IS",
#           "LR",
#           "MA",
#           "ML",
#           "MR",
#           "SL",
#           "SN",
#           "ST",
#           "TG",
#           "CV",
#           "AR",
#           "BR",
#           "CL",
#           "SR",
#           "UY",
#           "AG",
#           "BB",
#           "BO",
#           "BS",
#           "CA",
#           "CW",
#           "DM",
#           "DO",
#           "GD",
#           "GY",
#           "HT",
#           "KN",
#           "LC",
#           "PY",
#           "TT",
#           "US",
#           "VC",
#           "VE",
#           "CO",
#           "EC",
#           "JM",
#           "PA",
#           "PE",
#           "BZ",
#           "CR",
#           "GT",
#           "HN",
#           "MX",
#           "NI",
#           "SV"
#         ],
#         "disc_number": 1,
#         "duration_ms": 218986,
#         "explicit": false,
#         "external_ids": {
#           "isrc": "USNO11000089"
#         },
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/7dBtcqimoku2YOgAcaNvG0"
#         },
#         "href": "https://api.spotify.com/v1/tracks/7dBtcqimoku2YOgAcaNvG0",
#         "id": "7dBtcqimoku2YOgAcaNvG0",
#         "is_local": false,
#         "name": "Never Gonna Give You Up",
#         "popularity": 0,
#         "preview_url": "https://p.scdn.co/mp3-preview/8d8b2e52cb877a48b266d67c0a12e4607ec9f8ee?cid=03bc53377a004f35a1305a462e790be6",
#         "track_number": 22,
#         "type": "track",
#         "uri": "spotify:track:7dBtcqimoku2YOgAcaNvG0"
#       },
#       {
#         "album": {
#           "album_type": "compilation",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/0gxyHStUsqpMadRV0Di1Qt"
#               },
#               "href": "https://api.spotify.com/v1/artists/0gxyHStUsqpMadRV0Di1Qt",
#               "id": "0gxyHStUsqpMadRV0Di1Qt",
#               "name": "Rick Astley",
#               "type": "artist",
#               "uri": "spotify:artist:0gxyHStUsqpMadRV0Di1Qt"
#             }
#           ],
#           "available_markets": [
#             "AR",
#             "AU",
#             "AT",
#             "BE",
#             "BO",
#             "BR",
#             "BG",
#             "CA",
#             "CL",
#             "CO",
#             "CR",
#             "CY",
#             "CZ",
#             "DK",
#             "DO",
#             "DE",
#             "EC",
#             "EE",
#             "SV",
#             "FI",
#             "FR",
#             "GR",
#             "GT",
#             "HN",
#             "HK",
#             "HU",
#             "IS",
#             "IE",
#             "IT",
#             "LV",
#             "LT",
#             "LU",
#             "MY",
#             "MT",
#             "MX",
#             "NL",
#             "NZ",
#             "NI",
#             "NO",
#             "PA",
#             "PY",
#             "PE",
#             "PH",
#             "PL",
#             "PT",
#             "SG",
#             "SK",
#             "ES",
#             "SE",
#             "CH",
#             "TW",
#             "TR",
#             "UY",
#             "US",
#             "GB",
#             "AD",
#             "LI",
#             "MC",
#             "ID",
#             "JP",
#             "TH",
#             "VN",
#             "RO",
#             "IL",
#             "ZA",
#             "SA",
#             "AE",
#             "BH",
#             "QA",
#             "OM",
#             "KW",
#             "EG",
#             "MA",
#             "DZ",
#             "TN",
#             "LB",
#             "JO",
#             "PS",
#             "IN",
#             "BY",
#             "KZ",
#             "MD",
#             "UA",
#             "AL",
#             "BA",
#             "HR",
#             "ME",
#             "MK",
#             "RS",
#             "SI",
#             "KR",
#             "BD",
#             "PK",
#             "LK",
#             "GH",
#             "KE",
#             "NG",
#             "TZ",
#             "UG",
#             "AG",
#             "AM",
#             "BS",
#             "BB",
#             "BZ",
#             "BT",
#             "BW",
#             "BF",
#             "CV",
#             "CW",
#             "DM",
#             "FJ",
#             "GM",
#             "GE",
#             "GD",
#             "GW",
#             "GY",
#             "HT",
#             "JM",
#             "KI",
#             "LS",
#             "LR",
#             "MW",
#             "MV",
#             "ML",
#             "MH",
#             "FM",
#             "NA",
#             "NR",
#             "NE",
#             "PW",
#             "PG",
#             "PR",
#             "WS",
#             "SM",
#             "ST",
#             "SN",
#             "SC",
#             "SL",
#             "SB",
#             "KN",
#             "LC",
#             "VC",
#             "SR",
#             "TL",
#             "TO",
#             "TT",
#             "TV",
#             "VU",
#             "AZ",
#             "BN",
#             "BI",
#             "KH",
#             "CM",
#             "TD",
#             "KM",
#             "GQ",
#             "SZ",
#             "GA",
#             "GN",
#             "KG",
#             "LA",
#             "MO",
#             "MR",
#             "MN",
#             "NP",
#             "RW",
#             "TG",
#             "UZ",
#             "ZW",
#             "BJ",
#             "MG",
#             "MU",
#             "MZ",
#             "AO",
#             "CI",
#             "DJ",
#             "ZM",
#             "CD",
#             "CG",
#             "IQ",
#             "LY",
#             "TJ",
#             "VE",
#             "ET",
#             "XK"
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/6CWdaSQN5rsdDkOrhFcZ0E"
#           },
#           "href": "https://api.spotify.com/v1/albums/6CWdaSQN5rsdDkOrhFcZ0E",
#           "id": "6CWdaSQN5rsdDkOrhFcZ0E",
#           "images": [
#             {
#               "height": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b27339857471ba6d7315797dd6e7",
#               "width": 640
#             },
#             {
#               "height": 300,
#               "url": "https://i.scdn.co/image/ab67616d00001e0239857471ba6d7315797dd6e7",
#               "width": 300
#             },
#             {
#               "height": 64,
#               "url": "https://i.scdn.co/image/ab67616d0000485139857471ba6d7315797dd6e7",
#               "width": 64
#             }
#           ],
#           "name": "The Best of Me",
#           "release_date": "2019-12-29",
#           "release_date_precision": "day",
#           "total_tracks": 31,
#           "type": "album",
#           "uri": "spotify:album:6CWdaSQN5rsdDkOrhFcZ0E"
#         },
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/0gxyHStUsqpMadRV0Di1Qt"
#             },
#             "href": "https://api.spotify.com/v1/artists/0gxyHStUsqpMadRV0Di1Qt",
#             "id": "0gxyHStUsqpMadRV0Di1Qt",
#             "name": "Rick Astley",
#             "type": "artist",
#             "uri": "spotify:artist:0gxyHStUsqpMadRV0Di1Qt"
#           }
#         ],
#         "available_markets": [
#           "AR",
#           "AU",
#           "AT",
#           "BE",
#           "BO",
#           "BR",
#           "BG",
#           "CA",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DK",
#           "DO",
#           "DE",
#           "EC",
#           "EE",
#           "SV",
#           "FI",
#           "FR",
#           "GR",
#           "GT",
#           "HN",
#           "HK",
#           "HU",
#           "IS",
#           "IE",
#           "IT",
#           "LV",
#           "LT",
#           "LU",
#           "MY",
#           "MT",
#           "MX",
#           "NL",
#           "NZ",
#           "NI",
#           "NO",
#           "PA",
#           "PY",
#           "PE",
#           "PH",
#           "PL",
#           "PT",
#           "SG",
#           "SK",
#           "ES",
#           "SE",
#           "CH",
#           "TW",
#           "TR",
#           "UY",
#           "US",
#           "GB",
#           "AD",
#           "LI",
#           "MC",
#           "ID",
#           "JP",
#           "TH",
#           "VN",
#           "RO",
#           "IL",
#           "ZA",
#           "SA",
#           "AE",
#           "BH",
#           "QA",
#           "OM",
#           "KW",
#           "EG",
#           "MA",
#           "DZ",
#           "TN",
#           "LB",
#           "JO",
#           "PS",
#           "IN",
#           "BY",
#           "KZ",
#           "MD",
#           "UA",
#           "AL",
#           "BA",
#           "HR",
#           "ME",
#           "MK",
#           "RS",
#           "SI",
#           "KR",
#           "BD",
#           "PK",
#           "LK",
#           "GH",
#           "KE",
#           "NG",
#           "TZ",
#           "UG",
#           "AG",
#           "AM",
#           "BS",
#           "BB",
#           "BZ",
#           "BT",
#           "BW",
#           "BF",
#           "CV",
#           "CW",
#           "DM",
#           "FJ",
#           "GM",
#           "GE",
#           "GD",
#           "GW",
#           "GY",
#           "HT",
#           "JM",
#           "KI",
#           "LS",
#           "LR",
#           "MW",
#           "MV",
#           "ML",
#           "MH",
#           "FM",
#           "NA",
#           "NR",
#           "NE",
#           "PW",
#           "PG",
#           "WS",
#           "SM",
#           "ST",
#           "SN",
#           "SC",
#           "SL",
#           "SB",
#           "KN",
#           "LC",
#           "VC",
#           "SR",
#           "TL",
#           "TO",
#           "TT",
#           "TV",
#           "VU",
#           "AZ",
#           "BN",
#           "BI",
#           "KH",
#           "CM",
#           "TD",
#           "KM",
#           "GQ",
#           "SZ",
#           "GA",
#           "GN",
#           "KG",
#           "LA",
#           "MO",
#           "MR",
#           "MN",
#           "NP",
#           "RW",
#           "TG",
#           "UZ",
#           "ZW",
#           "BJ",
#           "MG",
#           "MU",
#           "MZ",
#           "AO",
#           "CI",
#           "DJ",
#           "ZM",
#           "CD",
#           "CG",
#           "IQ",
#           "LY",
#           "TJ",
#           "VE",
#           "ET",
#           "XK"
#         ],
#         "disc_number": 1,
#         "duration_ms": 213960,
#         "explicit": false,
#         "external_ids": {
#           "isrc": "GBARL9300135"
#         },
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/4L7qMw8HI3vM57hHRMyb4Y"
#         },
#         "href": "https://api.spotify.com/v1/tracks/4L7qMw8HI3vM57hHRMyb4Y",
#         "id": "4L7qMw8HI3vM57hHRMyb4Y",
#         "is_local": false,
#         "name": "Never Gonna Give You Up",
#         "popularity": 26,
#         "preview_url": "https://p.scdn.co/mp3-preview/9db1438d69cb3bb4db55bc6b16ba4485db8eeefe?cid=03bc53377a004f35a1305a462e790be6",
#         "track_number": 2,
#         "type": "track",
#         "uri": "spotify:track:4L7qMw8HI3vM57hHRMyb4Y"
#       },
#       {
#         "album": {
#           "album_type": "single",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/1zO3MgzmcwZLLNUQqeU2XH"
#               },
#               "href": "https://api.spotify.com/v1/artists/1zO3MgzmcwZLLNUQqeU2XH",
#               "id": "1zO3MgzmcwZLLNUQqeU2XH",
#               "name": "Hazlett",
#               "type": "artist",
#               "uri": "spotify:artist:1zO3MgzmcwZLLNUQqeU2XH"
#             }
#           ],
#           "available_markets": [
#             "AR",
#             "AU",
#             "AT",
#             "BE",
#             "BO",
#             "BR",
#             "BG",
#             "CA",
#             "CL",
#             "CO",
#             "CR",
#             "CY",
#             "CZ",
#             "DK",
#             "DO",
#             "DE",
#             "EC",
#             "EE",
#             "SV",
#             "FI",
#             "FR",
#             "GR",
#             "GT",
#             "HN",
#             "HK",
#             "HU",
#             "IS",
#             "IE",
#             "IT",
#             "LV",
#             "LT",
#             "LU",
#             "MY",
#             "MT",
#             "MX",
#             "NL",
#             "NZ",
#             "NI",
#             "NO",
#             "PA",
#             "PY",
#             "PE",
#             "PH",
#             "PL",
#             "PT",
#             "SG",
#             "SK",
#             "ES",
#             "SE",
#             "CH",
#             "TW",
#             "TR",
#             "UY",
#             "US",
#             "GB",
#             "AD",
#             "LI",
#             "MC",
#             "ID",
#             "JP",
#             "TH",
#             "VN",
#             "RO",
#             "IL",
#             "ZA",
#             "SA",
#             "AE",
#             "BH",
#             "QA",
#             "OM",
#             "KW",
#             "EG",
#             "MA",
#             "DZ",
#             "TN",
#             "LB",
#             "JO",
#             "PS",
#             "IN",
#             "BY",
#             "KZ",
#             "MD",
#             "UA",
#             "AL",
#             "BA",
#             "HR",
#             "ME",
#             "MK",
#             "RS",
#             "SI",
#             "KR",
#             "BD",
#             "PK",
#             "LK",
#             "GH",
#             "KE",
#             "NG",
#             "TZ",
#             "UG",
#             "AG",
#             "AM",
#             "BS",
#             "BB",
#             "BZ",
#             "BT",
#             "BW",
#             "BF",
#             "CV",
#             "CW",
#             "DM",
#             "FJ",
#             "GM",
#             "GE",
#             "GD",
#             "GW",
#             "GY",
#             "HT",
#             "JM",
#             "KI",
#             "LS",
#             "LR",
#             "MW",
#             "MV",
#             "ML",
#             "MH",
#             "FM",
#             "NA",
#             "NR",
#             "NE",
#             "PW",
#             "PG",
#             "PR",
#             "WS",
#             "SM",
#             "ST",
#             "SN",
#             "SC",
#             "SL",
#             "SB",
#             "KN",
#             "LC",
#             "VC",
#             "SR",
#             "TL",
#             "TO",
#             "TT",
#             "TV",
#             "VU",
#             "AZ",
#             "BN",
#             "BI",
#             "KH",
#             "CM",
#             "TD",
#             "KM",
#             "GQ",
#             "SZ",
#             "GA",
#             "GN",
#             "KG",
#             "LA",
#             "MO",
#             "MR",
#             "MN",
#             "NP",
#             "RW",
#             "TG",
#             "UZ",
#             "ZW",
#             "BJ",
#             "MG",
#             "MU",
#             "MZ",
#             "AO",
#             "CI",
#             "DJ",
#             "ZM",
#             "CD",
#             "CG",
#             "IQ",
#             "LY",
#             "TJ",
#             "VE",
#             "ET",
#             "XK"
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/3g0uQDl6eYPBGsbX9C3axd"
#           },
#           "href": "https://api.spotify.com/v1/albums/3g0uQDl6eYPBGsbX9C3axd",
#           "id": "3g0uQDl6eYPBGsbX9C3axd",
#           "images": [
#             {
#               "height": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b2731298c6e7de929d7efb011f9d",
#               "width": 640
#             },
#             {
#               "height": 300,
#               "url": "https://i.scdn.co/image/ab67616d00001e021298c6e7de929d7efb011f9d",
#               "width": 300
#             },
#             {
#               "height": 64,
#               "url": "https://i.scdn.co/image/ab67616d000048511298c6e7de929d7efb011f9d",
#               "width": 64
#             }
#           ],
#           "name": "Never Gonna Give You Up",
#           "release_date": "2019-06-07",
#           "release_date_precision": "day",
#           "total_tracks": 1,
#           "type": "album",
#           "uri": "spotify:album:3g0uQDl6eYPBGsbX9C3axd"
#         },
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/1zO3MgzmcwZLLNUQqeU2XH"
#             },
#             "href": "https://api.spotify.com/v1/artists/1zO3MgzmcwZLLNUQqeU2XH",
#             "id": "1zO3MgzmcwZLLNUQqeU2XH",
#             "name": "Hazlett",
#             "type": "artist",
#             "uri": "spotify:artist:1zO3MgzmcwZLLNUQqeU2XH"
#           }
#         ],
#         "available_markets": [
#           "AR",
#           "AU",
#           "AT",
#           "BE",
#           "BO",
#           "BR",
#           "BG",
#           "CA",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DK",
#           "DO",
#           "DE",
#           "EC",
#           "EE",
#           "SV",
#           "FI",
#           "FR",
#           "GR",
#           "GT",
#           "HN",
#           "HK",
#           "HU",
#           "IS",
#           "IE",
#           "IT",
#           "LV",
#           "LT",
#           "LU",
#           "MY",
#           "MT",
#           "MX",
#           "NL",
#           "NZ",
#           "NI",
#           "NO",
#           "PA",
#           "PY",
#           "PE",
#           "PH",
#           "PL",
#           "PT",
#           "SG",
#           "SK",
#           "ES",
#           "SE",
#           "CH",
#           "TW",
#           "TR",
#           "UY",
#           "US",
#           "GB",
#           "AD",
#           "LI",
#           "MC",
#           "ID",
#           "JP",
#           "TH",
#           "VN",
#           "RO",
#           "IL",
#           "ZA",
#           "SA",
#           "AE",
#           "BH",
#           "QA",
#           "OM",
#           "KW",
#           "EG",
#           "MA",
#           "DZ",
#           "TN",
#           "LB",
#           "JO",
#           "PS",
#           "IN",
#           "BY",
#           "KZ",
#           "MD",
#           "UA",
#           "AL",
#           "BA",
#           "HR",
#           "ME",
#           "MK",
#           "RS",
#           "SI",
#           "KR",
#           "BD",
#           "PK",
#           "LK",
#           "GH",
#           "KE",
#           "NG",
#           "TZ",
#           "UG",
#           "AG",
#           "AM",
#           "BS",
#           "BB",
#           "BZ",
#           "BT",
#           "BW",
#           "BF",
#           "CV",
#           "CW",
#           "DM",
#           "FJ",
#           "GM",
#           "GE",
#           "GD",
#           "GW",
#           "GY",
#           "HT",
#           "JM",
#           "KI",
#           "LS",
#           "LR",
#           "MW",
#           "MV",
#           "ML",
#           "MH",
#           "FM",
#           "NA",
#           "NR",
#           "NE",
#           "PW",
#           "PG",
#           "WS",
#           "SM",
#           "ST",
#           "SN",
#           "SC",
#           "SL",
#           "SB",
#           "KN",
#           "LC",
#           "VC",
#           "SR",
#           "TL",
#           "TO",
#           "TT",
#           "TV",
#           "VU",
#           "AZ",
#           "BN",
#           "BI",
#           "KH",
#           "CM",
#           "TD",
#           "KM",
#           "GQ",
#           "SZ",
#           "GA",
#           "GN",
#           "KG",
#           "LA",
#           "MO",
#           "MR",
#           "MN",
#           "NP",
#           "RW",
#           "TG",
#           "UZ",
#           "ZW",
#           "BJ",
#           "MG",
#           "MU",
#           "MZ",
#           "AO",
#           "CI",
#           "DJ",
#           "ZM",
#           "CD",
#           "CG",
#           "IQ",
#           "LY",
#           "TJ",
#           "VE",
#           "ET",
#           "XK"
#         ],
#         "disc_number": 1,
#         "duration_ms": 157787,
#         "explicit": false,
#         "external_ids": {
#           "isrc": "UK6KW1900033"
#         },
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/4VmJxOc6dQqgcVmZa8nWGK"
#         },
# ...
#             "MV",
#             "ML",
#             "MH",
#             "FM",
#             "NA",
#             "NR",
#             "NE",
#             "PW",
#             "PG",
#             "WS",
#             "SM",
#             "ST",
#             "SN",
#             "SC",
#             "SL",
#             "SB",
#             "KN",
#             "LC",
#             "VC",
#             "SR",
#             "TL",
#             "TO",
#             "TT",
#             "TV",
#             "VU",
#             "AZ",
#             "BN",
#             "BI",
#             "KH",
#             "CM",
#             "TD",
#             "KM",
#             "GQ",
#             "SZ",
#             "GA",
#             "GN",
#             "KG",
#             "LA",
#             "MO",
#             "MR",
#             "MN",
#             "NP",
#             "RW",
#             "TG",
#             "UZ",
#             "ZW",
#             "BJ",
#             "MG",
#             "MU",
#             "MZ",
#             "AO",
#             "CI",
#             "DJ",
#             "ZM",
#             "CD",
#             "CG",
#             "IQ",
#             "LY",
#             "TJ",
#             "VE",
#             "ET",
#             "XK"
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/2qIbHfs93z6eDwGoAdCkXA"
#           },
#           "href": "https://api.spotify.com/v1/albums/2qIbHfs93z6eDwGoAdCkXA",
#           "id": "2qIbHfs93z6eDwGoAdCkXA",
#           "images": [
#             {
#               "height": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b273b503cdb444b28826c4ca9217",
#               "width": 640
#             },
#             {
#               "height": 300,
#               "url": "https://i.scdn.co/image/ab67616d00001e02b503cdb444b28826c4ca9217",
#               "width": 300
#             },
#             {
#               "height": 64,
#               "url": "https://i.scdn.co/image/ab67616d00004851b503cdb444b28826c4ca9217",
#               "width": 64
#             }
#           ],
#           "name": "8 Letters",
#           "release_date": "2018-08-31",
#           "release_date_precision": "day",
#           "total_tracks": 8,
#           "type": "album",
#           "uri": "spotify:album:2qIbHfs93z6eDwGoAdCkXA"
#         },
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/2jnIB6XdLvnJUeNTy5A0J2"
#             },
#             "href": "https://api.spotify.com/v1/artists/2jnIB6XdLvnJUeNTy5A0J2",
#             "id": "2jnIB6XdLvnJUeNTy5A0J2",
#             "name": "Why Don't We",
#             "type": "artist",
#             "uri": "spotify:artist:2jnIB6XdLvnJUeNTy5A0J2"
#           }
#         ],
#         "available_markets": [
#           "AR",
#           "AU",
#           "AT",
#           "BE",
#           "BO",
#           "BR",
#           "BG",
#           "CA",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DK",
#           "DO",
#           "DE",
#           "EC",
#           "EE",
#           "SV",
#           "FI",
#           "FR",
#           "GR",
#           "GT",
#           "HN",
#           "HK",
#           "HU",
#           "IS",
#           "IE",
#           "IT",
#           "LV",
#           "LT",
#           "LU",
#           "MY",
#           "MT",
#           "MX",
#           "NL",
#           "NZ",
#           "NI",
#           "NO",
#           "PA",
#           "PY",
#           "PE",
#           "PH",
#           "PL",
#           "PT",
#           "SG",
#           "SK",
#           "ES",
#           "SE",
#           "CH",
#           "TW",
#           "TR",
#           "UY",
#           "US",
#           "GB",
#           "AD",
#           "LI",
#           "MC",
#           "ID",
#           "JP",
#           "TH",
#           "VN",
#           "RO",
#           "IL",
#           "ZA",
#           "SA",
#           "AE",
#           "BH",
#           "QA",
#           "OM",
#           "KW",
#           "EG",
#           "MA",
#           "DZ",
#           "TN",
#           "LB",
#           "JO",
#           "PS",
#           "IN",
#           "BY",
#           "KZ",
#           "MD",
#           "UA",
#           "AL",
#           "BA",
#           "HR",
#           "ME",
#           "MK",
#           "RS",
#           "SI",
#           "KR",
#           "BD",
#           "PK",
#           "LK",
#           "GH",
#           "KE",
#           "NG",
#           "TZ",
#           "UG",
#           "AG",
#           "AM",
#           "BS",
#           "BB",
#           "BZ",
#           "BT",
#           "BW",
#           "BF",
#           "CV",
#           "CW",
#           "DM",
#           "FJ",
#           "GM",
#           "GE",
#           "GD",
#           "GW",
#           "GY",
#           "HT",
#           "JM",
#           "KI",
#           "LS",
#           "LR",
#           "MW",
#           "MV",
#           "ML",
#           "MH",
#           "FM",
#           "NA",
#           "NR",
#           "NE",
#           "PW",
#           "PG",
#           "WS",
#           "SM",
#           "ST",
#           "SN",
#           "SC",
#           "SL",
#           "SB",
#           "KN",
#           "LC",
#           "VC",
#           "SR",
#           "TL",
#           "TO",
#           "TT",
#           "TV",
#           "VU",
#           "AZ",
#           "BN",
#           "BI",
#           "KH",
#           "CM",
#           "TD",
#           "KM",
#           "GQ",
#           "SZ",
#           "GA",
#           "GN",
#           "KG",
#           "LA",
#           "MO",
#           "MR",
#           "MN",
#           "NP",
#           "RW",
#           "TG",
#           "UZ",
#           "ZW",
#           "BJ",
#           "MG",
#           "MU",
#           "MZ",
#           "AO",
#           "CI",
#           "DJ",
#           "ZM",
#           "CD",
#           "CG",
#           "IQ",
#           "LY",
#           "TJ",
#           "VE",
#           "ET",
#           "XK"
#         ],
#         "disc_number": 1,
#         "duration_ms": 204906,
#         "explicit": false,
#         "external_ids": {
#           "isrc": "USAT21802300"
#         },
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/2N2s2s2w0jmSIPNZcm8Jnr"
#         },
#         "href": "https://api.spotify.com/v1/tracks/2N2s2s2w0jmSIPNZcm8Jnr",
#         "id": "2N2s2s2w0jmSIPNZcm8Jnr",
#         "is_local": false,
#         "name": "Hooked",
#         "popularity": 61,
#         "preview_url": "https://p.scdn.co/mp3-preview/cb712dc8bdb51d38c354083147db70530d755f77?cid=03bc53377a004f35a1305a462e790be6",
#         "track_number": 7,
#         "type": "track",
#         "uri": "spotify:track:2N2s2s2w0jmSIPNZcm8Jnr"
#       },
#       {
#         "album": {
#           "album_type": "album",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/3tFvFDca4inwWMY5vupFbX"
#               },
#               "href": "https://api.spotify.com/v1/artists/3tFvFDca4inwWMY5vupFbX",
#               "id": "3tFvFDca4inwWMY5vupFbX",
#               "name": "The Cooltrane Quartet",
#               "type": "artist",
#               "uri": "spotify:artist:3tFvFDca4inwWMY5vupFbX"
#             }
#           ],
#           "available_markets": [
#             "AR",
#             "AU",
#             "AT",
#             "BE",
#             "BO",
#             "BR",
#             "BG",
#             "CA",
#             "CL",
#             "CO",
#             "CR",
#             "CY",
#             "CZ",
#             "DK",
#             "DO",
#             "DE",
#             "EC",
#             "EE",
#             "SV",
#             "FI",
#             "FR",
#             "GR",
#             "GT",
#             "HN",
#             "HK",
#             "HU",
#             "IS",
#             "IE",
#             "IT",
#             "LV",
#             "LT",
#             "LU",
#             "MY",
#             "MT",
#             "MX",
#             "NL",
#             "NZ",
#             "NI",
#             "NO",
#             "PA",
#             "PY",
#             "PE",
#             "PH",
#             "PL",
#             "PT",
#             "SG",
#             "SK",
#             "ES",
#             "SE",
#             "CH",
#             "TW",
#             "TR",
#             "UY",
#             "US",
#             "GB",
#             "AD",
#             "LI",
#             "MC",
#             "ID",
#             "JP",
#             "TH",
#             "VN",
#             "RO",
#             "IL",
#             "ZA",
#             "SA",
#             "AE",
#             "BH",
#             "QA",
#             "OM",
#             "KW",
#             "EG",
#             "MA",
#             "DZ",
#             "TN",
#             "LB",
#             "JO",
#             "PS",
#             "IN",
#             "BY",
#             "KZ",
#             "MD",
#             "UA",
#             "AL",
#             "BA",
#             "HR",
#             "ME",
#             "MK",
#             "RS",
#             "SI",
#             "KR",
#             "BD",
#             "PK",
#             "LK",
#             "GH",
#             "KE",
#             "NG",
#             "TZ",
#             "UG",
#             "AG",
#             "AM",
#             "BS",
#             "BB",
#             "BZ",
#             "BT",
#             "BW",
#             "BF",
#             "CV",
#             "CW",
#             "DM",
#             "FJ",
#             "GM",
#             "GE",
#             "GD",
#             "GW",
#             "GY",
#             "HT",
#             "JM",
#             "KI",
#             "LS",
#             "LR",
#             "MW",
#             "MV",
#             "ML",
#             "MH",
#             "FM",
#             "NA",
#             "NR",
#             "NE",
#             "PW",
#             "PG",
#             "PR",
#             "WS",
#             "SM",
#             "ST",
#             "SN",
#             "SC",
#             "SL",
#             "SB",
#             "KN",
#             "LC",
#             "VC",
#             "SR",
#             "TL",
#             "TO",
#             "TT",
#             "TV",
#             "VU",
#             "AZ",
#             "BN",
#             "BI",
#             "KH",
#             "CM",
#             "TD",
#             "KM",
#             "GQ",
#             "SZ",
#             "GA",
#             "GN",
#             "KG",
#             "LA",
#             "MO",
#             "MR",
#             "MN",
#             "NP",
#             "RW",
#             "TG",
#             "UZ",
#             "ZW",
#             "BJ",
#             "MG",
#             "MU",
#             "MZ",
#             "AO",
#             "CI",
#             "DJ",
#             "ZM",
#             "CD",
#             "CG",
#             "IQ",
#             "LY",
#             "TJ",
#             "VE",
#             "ET",
#             "XK"
#           ],
#           "external_urls": {
#             "spotify": "https://open.spotify.com/album/1F2JsrJUWW8UL9fTU41yqv"
#           },
#           "href": "https://api.spotify.com/v1/albums/1F2JsrJUWW8UL9fTU41yqv",
#           "id": "1F2JsrJUWW8UL9fTU41yqv",
#           "images": [
#             {
#               "height": 640,
#               "url": "https://i.scdn.co/image/ab67616d0000b273a720607dc70ae743d187f201",
#               "width": 640
#             },
#             {
#               "height": 300,
#               "url": "https://i.scdn.co/image/ab67616d00001e02a720607dc70ae743d187f201",
#               "width": 300
#             },
#             {
#               "height": 64,
#               "url": "https://i.scdn.co/image/ab67616d00004851a720607dc70ae743d187f201",
#               "width": 64
#             }
#           ],
#           "name": "Songs We Love",
#           "release_date": "2021-04-02",
#           "release_date_precision": "day",
#           "total_tracks": 11,
#           "type": "album",
#           "uri": "spotify:album:1F2JsrJUWW8UL9fTU41yqv"
#         },
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3tFvFDca4inwWMY5vupFbX"
#             },
#             "href": "https://api.spotify.com/v1/artists/3tFvFDca4inwWMY5vupFbX",
#             "id": "3tFvFDca4inwWMY5vupFbX",
#             "name": "The Cooltrane Quartet",
#             "type": "artist",
#             "uri": "spotify:artist:3tFvFDca4inwWMY5vupFbX"
#           },
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/6NP40ldgw4kYtspZOziuii"
#             },
#             "href": "https://api.spotify.com/v1/artists/6NP40ldgw4kYtspZOziuii",
#             "id": "6NP40ldgw4kYtspZOziuii",
#             "name": "Eve St. Jones",
#             "type": "artist",
#             "uri": "spotify:artist:6NP40ldgw4kYtspZOziuii"
#           }
#         ],
#         "available_markets": [
#           "AR",
#           "AU",
#           "AT",
#           "BE",
#           "BO",
#           "BR",
#           "BG",
#           "CA",
#           "CL",
#           "CO",
#           "CR",
#           "CY",
#           "CZ",
#           "DK",
#           "DO",
#           "DE",
#           "EC",
#           "EE",
#           "SV",
#           "FI",
#           "FR",
#           "GR",
#           "GT",
#           "HN",
#           "HK",
#           "HU",
#           "IS",
#           "IE",
#           "IT",
#           "LV",
#           "LT",
#           "LU",
#           "MY",
#           "MT",
#           "MX",
#           "NL",
#           "NZ",
#           "NI",
#           "NO",
#           "PA",
#           "PY",
#           "PE",
#           "PH",
#           "PL",
#           "PT",
#           "SG",
#           "SK",
#           "ES",
#           "SE",
#           "CH",
#           "TW",
#           "TR",
#           "UY",
#           "US",
#           "GB",
#           "AD",
#           "LI",
#           "MC",
#           "ID",
#           "JP",
#           "TH",
#           "VN",
#           "RO",
#           "IL",
#           "ZA",
#           "SA",
#           "AE",
#           "BH",
#           "QA",
#           "OM",
#           "KW",
#           "EG",
#           "MA",
#           "DZ",
#           "TN",
#           "LB",
#           "JO",
#           "PS",
#           "IN",
#           "BY",
#           "KZ",
#           "MD",
#           "UA",
#           "AL",
#           "BA",
#           "HR",
#           "ME",
#           "MK",
#           "RS",
#           "SI",
#           "KR",
#           "BD",
#           "PK",
#           "LK",
#           "GH",
#           "KE",
#           "NG",
#           "TZ",
#           "UG",
#           "AG",
#           "AM",
#           "BS",
#           "BB",
#           "BZ",
#           "BT",
#           "BW",
#           "BF",
#           "CV",
#           "CW",
#           "DM",
#           "FJ",
#           "GM",
#           "GE",
#           "GD",
#           "GW",
#           "GY",
#           "HT",
#           "JM",
#           "KI",
#           "LS",
#           "LR",
#           "MW",
#           "MV",
#           "ML",
#           "MH",
#           "FM",
#           "NA",
#           "NR",
#           "NE",
#           "PW",
#           "PG",
#           "WS",
#           "SM",
#           "ST",
#           "SN",
#           "SC",
#           "SL",
#           "SB",
#           "KN",
#           "LC",
#           "VC",
#           "SR",
#           "TL",
#           "TO",
#           "TT",
#           "TV",
#           "VU",
#           "AZ",
#           "BN",
#           "BI",
#           "KH",
#           "CM",
#           "TD",
#           "KM",
#           "GQ",
#           "SZ",
#           "GA",
#           "GN",
#           "KG",
#           "LA",
#           "MO",
#           "MR",
#           "MN",
#           "NP",
#           "RW",
#           "TG",
#           "UZ",
#           "ZW",
#           "BJ",
#           "MG",
#           "MU",
#           "MZ",
#           "AO",
#           "CI",
#           "DJ",
#           "ZM",
#           "CD",
#           "CG",
#           "IQ",
#           "LY",
#           "TJ",
#           "VE",
#           "ET",
#           "XK"
#         ],
#         "disc_number": 1,
#         "duration_ms": 187969,
#         "explicit": false,
#         "external_ids": {
#           "isrc": "ARF412100032"
#         },
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/2oD3ivFZnfyciys07pNXoN"
#         },
#         "href": "https://api.spotify.com/v1/tracks/2oD3ivFZnfyciys07pNXoN",
#         "id": "2oD3ivFZnfyciys07pNXoN",
#         "is_local": false,
#         "name": "Never Gonna Give You Up",
#         "popularity": 57,
#         "preview_url": "https://p.scdn.co/mp3-preview/80c9ed6040a60a1e96fabf5f59a34f874cc4a609?cid=03bc53377a004f35a1305a462e790be6",
#         "track_number": 4,
#         "type": "track",
#         "uri": "spotify:track:2oD3ivFZnfyciys07pNXoN"
#       }
#     ],
#     "limit": 10,
#     "next": "https://api.spotify.com/v1/search?query=Never+Gonna+Give+You+Up&type=track&offset=10&limit=10",
#     "offset": 0,
#     "previous": null,
#     "total": 811
#   }
# }

# %%
import requests


# https://developer.spotify.com/documentation/web-api/reference/get-an-artists-top-tracks
def get_artists_top_tracks(artist_id, access_token, country_code="US"):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {"market": country_code}
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        return response.json()


# Example usage
artist_id = "3TVXtAsR1Inumwj472S9r4"  # Spotify ID
access_token = "BQD3fo0yDacBQITWVBTLtkz5JrFii7SVswbmVZ0khVViCIFnhpMMARVBOMocQw7vxXG9Qkg_3a04JKl13PcERE8oh8EOZOzcgz4hL246YZBJtqzgs3Q"
top_tracks = get_artists_top_tracks(artist_id, access_token)
# print(top_tracks)

# print(json.dumps(top_tracks, indent=2))

# how can we print out all the track names
for track in top_tracks["tracks"]:
    print(track["name"])
# Out:
# Rich Baby Daddy (feat. Sexyy Red & SZA)
# One Dance
# IDGAF (feat. Yeat)
# First Person Shooter (feat. J. Cole)
# Jimmy Cooks (feat. 21 Savage)
# act ii: date @ 8 (feat. Drake) - remix
# God's Plan
# Passionfruit
# MELTDOWN (feat. Drake)
# Fair Trade (with Travis Scott)

# %%
for track in top_tracks["tracks"]:
    print(track["name"])

# %%
import requests

# https://developer.spotify.com/documentation/web-api/reference/get-playlists-tracks
def get_playlist_tracks(playlist_id, access_token):
    url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"
    headers = {"Authorization": f"Bearer {access_token}"}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        return response.json()  # This will include error information


# Example usage
playlist_id = "37i9dQZEVXbMDoHDwVN2tF"  # Example: Spotify's "Global Top 50" playlist ID
access_token = "BQD3fo0yDacBQITWVBTLtkz5JrFii7SVswbmVZ0khVViCIFnhpMMARVBOMocQw7vxXG9Qkg_3a04JKl13PcERE8oh8EOZOzcgz4hL246YZBJtqzgs3Q"
playlist_tracks = get_playlist_tracks(playlist_id, access_token)
# print(playlist_tracks)

# pretty print the json
# print(json.dumps(playlist_tracks, indent=2))

# print the track names
for item in playlist_tracks["items"]:
    track = item["track"]
    print(track["name"])
# Out:
# Beautiful Things
# End of Beginning
# we can't be friends (wait for your love)
# i like the way you kiss me
# Like That
# Too Sweet
# TEXAS HOLD 'EM
# Gata Only
# greedy
# CARNIVAL
# Lose Control
# Cruel Summer
# One Of The Girls (with JENNIE, Lily Rose Depp)
# Magnetic
# My Love Mine All Mine
# Madonna
# LUNA
# II MOST WANTED
# Stick Season
# La Diabla
# FE!N (feat. Playboi Carti)
# intro (end of the world)
# Saturn
# Type Shit
# I Wanna Be Yours
# Corazón de Piedra
# redrum
# LA FALDA
# JOLENE
# Unwritten
# Cinderella
# LA PEOPLE II
# Scared To Start
# obsessed
# Water
# Lovin On Me
# Seven (feat. Latto) (Explicit Ver.)
# Like Crazy
# Starboy
# yes, and?
# Training Season
# Austin
# I Remember Everything (feat. Kacey Musgraves)
# BODYGUARD
# Houdini
# The Night We Met
# Whatever She Wants
# FRI(END)S
# the boy is mine
# PERRO NEGRO

# %%
# print the track names
for item in playlist_tracks["items"]:
    track = item["track"]
    print(track["name"])

# %%
# Essential imports
from bs4 import BeautifulSoup

# %%
# Mock HTML content
html_content = """
<html>
    <head>
        <title>My Test Page</title>
    </head>
    <body>
        <h1>Welcome to My Test Page</h1>
        <p class="description">This is a test page for demonstrating Beautiful Soup basics.</p>
        <div class="container">
            <p class="item">Item 1</p>
            <p class="item">Item 2</p>
        </div>
        <div id="unique-element-id">
            <p>This is a unique element.</p>
        </div>
    </body>
</html>
"""

# Creating a soup object from HTML content
soup = BeautifulSoup(html_content, "html.parser")

# %%
# Accessing tag names
title_tag = soup.title
print(title_tag)  # Outputs: <title>My Test Page</title>

# Getting the name of the tag
print(title_tag.name)  # Outputs: title

# Accessing tag text
print(title_tag.string)  # Outputs: My Test Page

# Finding a single element
first_paragraph = soup.find("p")
print(first_paragraph)  # Outputs the first <p> tag

# Finding all elements of a tag
all_paragraphs = soup.find_all("p")
print(all_paragraphs)  # Outputs all <p> tags
# Out:
# <title>My Test Page</title>
# title
# My Test Page
# <p class="description">This is a test page for demonstrating Beautiful Soup basics.</p>
# [<p class="description">This is a test page for demonstrating Beautiful Soup basics.</p>, <p class="item">Item 1</p>, <p class="item">Item 2</p>, <p>This is a unique element.</p>]

# %%
# search using some string
# want to find the elemnt that says "test"
test_element = soup.find(string="My Test Page")
print(test_element)
print(test_element.parent)
# Out:
# My Test Page
# <title>My Test Page</title>

# %%
# Finding elements by class name
description = soup.find_all("p", class_="description")
print(description[0].text)

element_with_id = soup.find(id="unique-element-id")
print(element_with_id)
# Out:
# This is a test page for demonstrating Beautiful Soup basics.
# <div id="unique-element-id">
# <p>This is a unique element.</p>
# </div>

# %%
# Finding the element with id 'unique-element-id'
unique_element = soup.find(id="unique-element-id")

# Finding the <p> tag within this unique element
p_tag_within_unique_element = unique_element.find("p")

# Accessing the text inside the <p> tag
text_inside_p_tag = p_tag_within_unique_element.text

print(text_inside_p_tag)
# Out:
# This is a unique element.

# %%
# Navigating to a parent
item_parent = soup.find(class_="item").find_parent("div")
print(item_parent)

# Navigating siblings
first_item = soup.find(class_="item")
second_item = first_item.find_next_sibling("p")
print(second_item.text)
# Out:
# <div class="container">
# <p class="item">Item 1</p>
# <p class="item">Item 2</p>
# </div>
# Item 2

# %%
# Extracting all items within the 'container' class
container = soup.find("div", class_="container")
items = container.find_all("p", class_="item")

for item in items:
    print(item.text)
# Out:
# Item 1
# Item 2

# %%
# What's the price of this item?
response = requests.get("https://verdephiladelphia.com/products/chill-tips-wavy-baby")

# lets implement it!
page = BeautifulSoup(response.text, "html.parser")

tag = page.find("span", class_="current-price theme-money")
txt = tag.text
value = txt[1:]
dollar_value = float(value)
print(dollar_value)
# Out:
# 20.0

# %%
# make a get request to https://verdephiladelphia.com/products/chill-tips-wavy-baby
response = requests.get("https://verdephiladelphia.com/products/chill-tips-wavy-baby")

# now we can use beautiful soup to parse the content
soup = BeautifulSoup(response.text, "html.parser")

# find a $ that has a 'span' parent
price = soup.find("span", class_="current-price")
print(price.text[1:])

# %%
# make a get request to https://verdephiladelphia.com/products/chill-tips-wavy-baby
response = requests.get("https://verdephiladelphia.com/products/chill-tips-wavy-baby")

# now we can use beautiful soup to parse the content
soup = BeautifulSoup(response.text, "html.parser")

import re

# find a "$" that has a 'span' parent tag
price = soup.find(string=re.compile("^\$"))
print(price.parent.text)
# Out:
# $20.00

# %%
import re

# Sample text to search within
text = "The rain in Spain"

# Simple pattern matching: finding the word "Spain" in the text
pattern = "Spain"
match = re.search(pattern, text)

# If the pattern is found, print the match
if match:
    print("Found:", match.group())
else:
    print("Not found.")

# %%
text = "The rain in Spain"

# The dot (.) symbol matches any character except newline
pattern = "r.in"
matches = re.findall(pattern, text)

print("Matches found:", matches)

# %%
text = "The rain in Spain"

# ^ and $ denote the beginning and end of a string respectively
pattern = "^The.*Spain$"
match = re.search(pattern, text)

# Check if the pattern matches
if match:
    print("The string starts with 'The' and ends with 'Spain'")
else:
    print("Pattern not found")

# %%
# Searching for digits in a string
text = "The 2 dogs have 4 eyes."
pattern = "\d"  # \d matches any digit
matches = re.findall(pattern, text)

print("Digits found:", matches)

# %%
# Using quantifiers to find repeated characters
pattern = "a{2}"  # Looks for two consecutive 'a's
matches = re.findall(pattern, "The rain in Spain mainly stays in the plain")

print("Matches found:", matches)

# %%
text = "The rain in Spain"

# Finding patterns that match either 'rain' or 'Spain'
pattern = "(rain|Spain)"
matches = re.findall(pattern, text)

print("Matches found:", matches)

# %%
text = """
Once upon a time, in the magical amhara kingdom of Regexland, there lived a brave hero named Alphanum3ric. 
Alphanum3ric was on a quest to find the legendary digits of destiny, rumored to be hidden within 
the depths of StringValley. Accompanied by his faithful companion, DigitDog99, they set out from 
their home in VariableVillage.
"""

pattern = "a.{4}a"
matches = re.findall(pattern, text)

print("Matches found:", matches)
